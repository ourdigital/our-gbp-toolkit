# %% [markdown]
# <a href="https://colab.research.google.com/github/ourdigital/our-gbp-toolkit/blob/main/Data%20Analysis/Level%201/Pandas_for_Data_Analysis_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas for Data Analysis
# This notebook provides a beginner-friendly walkthrough of key pandas functionalities using simple examples. Topics include:
# - Reading data from CSV, Excel, and JSON
# - Selecting and filtering rows and columns
# - Merging, joining, and concatenating datasets
# - Grouping and aggregating data
# - Applying functions with `.apply()`, `.map()`, and `.lambda`
# - Transforming data with `.pivot()`, `.melt()`, `.stack()`, `.unstack()`

# %%
# Importing required libraries
import pandas as pd
import numpy as np
import json

# %% [markdown]
# ## Reading Data
# We'll create small example files and read them using pandas.

# %%
# Read CSV
df_csv = pd.read_csv('/content/JHR-IG-All-Adset-20260406.csv')
df_csv
# Out:
#                                광고 이름       연령  \
# 0                                NaN      NaN
# 1    IG_트래픽_JHR_2026 랜쇼페 티징_20260323    35-44
# 2    IG_트래픽_JHR_2026 랜쇼페 티징_20260323    35-44
# 3    IG_트래픽_JHR_2026 랜쇼페 티징_20260323    25-34
# 4    IG_트래픽_JHR_2026 랜쇼페 티징_20260323    25-34
# ..                               ...      ...
# 149  IG_트래픽_WJB_2026 랜쇼페 식음_20260401  Unknown
# 150  IG_트래픽_JHR_2026 랜쇼페 티징_20260323  Unknown
# 151  IG_트래픽_GJJ_2026 랜쇼페 식음_20260401  Unknown
# 152  IG_트래픽_GJB_2026 랜쇼페 식음_20260401  Unknown
# 153  IG_트래픽_JHR_2026 랜쇼페 연회_20260401  Unknown
#
#                                   광고           목표        행동 유도     광고 게재  \
# 0                                NaN          NaN          NaN       NaN
# 1    IG_트래픽_JHR_2026 랜쇼페 티징_20260323  LINK_CLICKS   LEARN_MORE  inactive
# 2    IG_트래픽_JHR_2026 랜쇼페 티징_20260323  LINK_CLICKS   LEARN_MORE  inactive
# 3    IG_트래픽_JHR_2026 랜쇼페 티징_20260323  LINK_CLICKS   LEARN_MORE  inactive
# 4    IG_트래픽_JHR_2026 랜쇼페 티징_20260323  LINK_CLICKS   LEARN_MORE  inactive
# ..                               ...          ...          ...       ...
# 149  IG_트래픽_WJB_2026 랜쇼페 식음_20260401  LINK_CLICKS  BOOK_TRAVEL    active
# 150  IG_트래픽_JHR_2026 랜쇼페 티징_20260323  LINK_CLICKS   LEARN_MORE  inactive
# 151  IG_트래픽_GJJ_2026 랜쇼페 식음_20260401  LINK_CLICKS  BOOK_TRAVEL    active
# 152  IG_트래픽_GJB_2026 랜쇼페 식음_20260401  LINK_CLICKS  BOOK_TRAVEL    active
# 153  IG_트래픽_JHR_2026 랜쇼페 연회_20260401  LINK_CLICKS   LEARN_MORE    active
#
#           도달       노출        빈도  결과 유형  ...      결과당 비용  지출 금액 (KRW)  \
# 0    1226491  3550315  2.894693    NaN  ...         NaN     17039215
# 1      26649    37629  1.412023  링크 클릭  ...  207.238994       230657
# 2      42731    62614  1.465306  링크 클릭  ...  143.472065       228551
# 3      28257    39447  1.396008  링크 클릭  ...  228.179518       189389
# 4      39095    58262  1.490267  링크 클릭  ...  153.325602       171878
# ..       ...      ...       ...    ...  ...         ...          ...
# 149        1        1  1.000000  링크 클릭  ...         NaN           10
# 150        2        2  1.000000  링크 클릭  ...         NaN            4
# 151        1        1  1.000000  링크 클릭  ...    3.000000            3
# 152        1        1  1.000000  링크 클릭  ...         NaN            3
# 153        1        1  1.000000  링크 클릭  ...         NaN            3
#
#              시작          종료 CPM(1,000회 노출당 비용)    링크 클릭  CPC(링크 클릭당 비용)  \
# 0           NaN         NaN        4799.353015  61310.0      277.919018
# 1    2026-03-23  2026-03-31        6129.766935   1113.0      207.238994
# 2    2026-03-23  2026-03-31        3650.158112   1593.0      143.472065
# 3    2026-03-23  2026-03-31        4801.100210    830.0      228.179518
# 4    2026-03-23  2026-03-31        2950.087536   1121.0      153.325602
# ..          ...         ...                ...      ...             ...
# 149  2026-04-01  2026-04-12       10000.000000      NaN             NaN
# 150  2026-03-23  2026-03-31        2000.000000      NaN             NaN
# 151  2026-04-01  2026-04-12        3000.000000      1.0        3.000000
# 152  2026-04-01  2026-04-12        3000.000000      NaN             NaN
# 153  2026-04-01  2026-04-12        3000.000000      NaN             NaN
#
#      CTR(링크 클릭률)       보고 시작       보고 종료
# 0       1.726889  2026-01-01  2026-04-06
# 1       2.957825  2026-01-01  2026-04-06
# 2       2.544159  2026-01-01  2026-04-06
# 3       2.104089  2026-01-01  2026-04-06
# 4       1.924067  2026-01-01  2026-04-06
# ..           ...         ...         ...
# 149          NaN  2026-01-01  2026-04-06
# 150          NaN  2026-01-01  2026-04-06
# 151   100.000000  2026-01-01  2026-04-06
# 152          NaN  2026-01-01  2026-04-06
# 153          NaN  2026-01-01  2026-04-06
#
# [154 rows x 21 columns]

# %%
df_csv = df_csv.drop(df_csv.index[0])
display(df_csv.head())
# Out:
#                              광고 이름     연령                               광고  \
# 1  IG_트래픽_JHR_2026 랜쇼페 티징_20260323  35-44  IG_트래픽_JHR_2026 랜쇼페 티징_20260323
# 2  IG_트래픽_JHR_2026 랜쇼페 티징_20260323  35-44  IG_트래픽_JHR_2026 랜쇼페 티징_20260323
# 3  IG_트래픽_JHR_2026 랜쇼페 티징_20260323  25-34  IG_트래픽_JHR_2026 랜쇼페 티징_20260323
# 4  IG_트래픽_JHR_2026 랜쇼페 티징_20260323  25-34  IG_트래픽_JHR_2026 랜쇼페 티징_20260323
# 5  IG_트래픽_GJJ_2026 랜쇼페 객실_20260401  35-44  IG_트래픽_GJJ_2026 랜쇼페 객실_20260401
#
#             목표        행동 유도     광고 게재     도달     노출        빈도  결과 유형  ...  \
# 1  LINK_CLICKS   LEARN_MORE  inactive  26649  37629  1.412023  링크 클릭  ...
# 2  LINK_CLICKS   LEARN_MORE  inactive  42731  62614  1.465306  링크 클릭  ...
# 3  LINK_CLICKS   LEARN_MORE  inactive  28257  39447  1.396008  링크 클릭  ...
# 4  LINK_CLICKS   LEARN_MORE  inactive  39095  58262  1.490267  링크 클릭  ...
# 5  LINK_CLICKS  BOOK_TRAVEL    active  13781  22296  1.617880  링크 클릭  ...
#
#        결과당 비용  지출 금액 (KRW)          시작          종료 CPM(1,000회 노출당 비용)   링크 클릭  \
# 1  207.238994       230657  2026-03-23  2026-03-31        6129.766935  1113.0
# 2  143.472065       228551  2026-03-23  2026-03-31        3650.158112  1593.0
# 3  228.179518       189389  2026-03-23  2026-03-31        4801.100210   830.0
# 4  153.325602       171878  2026-03-23  2026-03-31        2950.087536  1121.0
# 5   80.081621       140303  2026-04-01  2026-04-12        6292.743093  1752.0
#
#    CPC(링크 클릭당 비용)  CTR(링크 클릭률)       보고 시작       보고 종료
# 1      207.238994     2.957825  2026-01-01  2026-04-06
# 2      143.472065     2.544159  2026-01-01  2026-04-06
# 3      228.179518     2.104089  2026-01-01  2026-04-06
# 4      153.325602     1.924067  2026-01-01  2026-04-06
# 5       80.081621     7.857912  2026-01-01  2026-04-06
#
# [5 rows x 21 columns]
